# %%
from get_stock_price import handler

# %%
verbose=True
stock_input_file = 'stock_input_short_2.txt'
handler(verbose, stock_input_file)
# Out:
# Visiting https://finance.yahoo.com/quote/NVS/?p=NVS
# Status 200
# Novartis AG (NVS)
# NYSE - Nasdaq Real Time Price • USD
# {'full_name': 'Novartis AG', 'market': 'NYSE', 'curency': 'USD'}
# {'full_name': 'Novartis AG', 'market': 'NYSE', 'curency': 'USD', 'volume': 1567286.0, 'prev_close': 102.26, 'curr_price': 103.29, 'market_cap': 211573000000.0, 'divi_abs': '3.78', 'divi_p': '3.69'}
# *** Fetching historic data from https://finance.yahoo.com/quote/NVS/history?p=NVS
# *** Clicking away annoying pop-ups ***
# button 0
# button 1
# button 2
# button failed
# *** Clicking the time dropdown menu ***
# dropdown block B
# <selenium.webdriver.remote.webelement.WebElement (session="d7baa6a4c6d176f71151dce0c8cf8701", element="f.C3C71AC3D9516AB804A2725FD6A0C5F6.d.5FD31976FF59FD36BE87DA5B549DFA41.e.59")>
# May 14, 2023 - May 14, 2024
# *** Clicking on "Max" to get all time data ***
# *** Locating download link ***
# *** Retrieving data ***
# ...
